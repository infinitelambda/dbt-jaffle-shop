# %%
import json
# import pydantic

# %%
import pandas as pd

# %%
with open("../target/manifest.json") as f:
    data = json.load(f)

# %%
with open("../target/catalog.json") as f:
    catalog = json.load(f)

# %%
# def get_types(node):
#     columns = node['columns']
#     tup_columns = [(node['unique_id'], col['name'].lower(), col['type']) for col in columns.values()]
#     return tup_columns

# %% [markdown]
# from typing import Dict, List, Optional
# from enum import Enum
# from pathlib import Path
#
# from pydantic import BaseModel, validator
#
#
# class DbtResourceType(str, Enum):
#     model = 'model'
#     analysis = 'analysis'
#     test = 'test'
#     operation = 'operation'
#     seed = 'seed'
#     source = 'source'
#
#
# class DbtMaterializationType(str, Enum):
#     table = 'table'
#     view = 'view'
#     incremental = 'incremental'
#     ephemeral = 'ephemeral'
#     seed = 'seed'
#     materialized = 'materialzed'
#     test = 'test'
#
# # class Column(BaseModel):
# #     name = str
# #     description = str
#
# # class Columns(BaseModel):
# #     columns: List[Column]
#
# class NodeDeps(BaseModel):
#     nodes: List[str]
#
#
# class NodeConfig(BaseModel):
#     materialized: Optional[DbtMaterializationType]
#
#
# class Node(BaseModel):
#     unique_id: str
#     path: Path
#     resource_type: DbtResourceType
#     description: str
#     depends_on: Optional[NodeDeps]
#     config: NodeConfig
# #     columns: Optional[Columns]
#
#
# class Manifest(BaseModel):
#     nodes: Dict["str", Node]
#     sources: Dict["str", Node]
#
#     @validator('nodes', 'sources')
#     def filter(cls, val):
#         return {k: v for k, v in val.items() if v.resource_type.value in ('model', 'seed', 'source')}
#
#
# m = Manifest(**data)
# # print(m)
#
# m.nodes
#
# m.nodes['model.jaffle_shop.orders']

# %%
tables = [node for node in data['nodes'] if node[:5] =='model']

# %%
def get_columns(table):
    columns = table['columns']
    tup_columns = [(table['relation_name'],table['name'],table['unique_id'], col['name'], col['description']) for col in columns.values()]
    return tup_columns

# %%
tests_l = [node for node in list(data['nodes'].keys()) if node[:4]=='test']

# %%
def parse_test(test):
    tup = (test['unique_id'],
           test[ "test_metadata"]['name'],
           test[ "test_metadata"]['kwargs']['column_name'],
           test['depends_on']['nodes'][0],
           test['compiled_sql'].strip()
          )
    return tup

# %%
def parse_tests(list_tests):
    tests = [parse_test(test_values) for _, test_values in list_tests.items()]
    return tests

# %%
ts = {key:value for key, value in data['nodes'].items() if key in tests_l}

# %%
tests_df = pd.DataFrame(parse_tests(ts), columns =['test_id', 'test_type', 'column_name', 'node', 'test_sql'])

# %%
# # Save the original `to_html` function to call it later
# pd.DataFrame.base_to_html = pd.DataFrame.to_html
# # Call it here in a controlled way
# pd.DataFrame.to_html = (
#     lambda df, *args, **kwargs: 
#         (df.base_to_html(*args, **kwargs)
#            .replace(r"\n", "<br/>"))
# )

# %%
column_list = []
for table in tables:
    column_list.extend(get_columns(data['nodes'][table]))

# %%
columns_df = pd.DataFrame(column_list,
                          columns = ['relation', 'table_name', 'node', 'column_name','description']
                         )

# %%
columns_df
# Out:
#                            relation     table_name  \
# 0       DBT_TABLEAU.DAVID.customers      customers
# 1       DBT_TABLEAU.DAVID.customers      customers
# 2       DBT_TABLEAU.DAVID.customers      customers
# 3       DBT_TABLEAU.DAVID.customers      customers
# 4       DBT_TABLEAU.DAVID.customers      customers
# 5       DBT_TABLEAU.DAVID.customers      customers
# 6       DBT_TABLEAU.DAVID.customers      customers
# 7          DBT_TABLEAU.DAVID.orders         orders
# 8          DBT_TABLEAU.DAVID.orders         orders
# 9          DBT_TABLEAU.DAVID.orders         orders
# 10         DBT_TABLEAU.DAVID.orders         orders
# 11         DBT_TABLEAU.DAVID.orders         orders
# 12         DBT_TABLEAU.DAVID.orders         orders
# 13         DBT_TABLEAU.DAVID.orders         orders
# 14         DBT_TABLEAU.DAVID.orders         orders
# 15         DBT_TABLEAU.DAVID.orders         orders
# 16  DBT_TABLEAU.DAVID.stg_customers  stg_customers
# 17   DBT_TABLEAU.DAVID.stg_payments   stg_payments
# 18   DBT_TABLEAU.DAVID.stg_payments   stg_payments
# 19     DBT_TABLEAU.DAVID.stg_orders     stg_orders
# 20     DBT_TABLEAU.DAVID.stg_orders     stg_orders
#
#                                node              column_name  \
# 0       model.jaffle_shop.customers              customer_id
# 1       model.jaffle_shop.customers               first_name
# 2       model.jaffle_shop.customers                last_name
# 3       model.jaffle_shop.customers              first_order
# 4       model.jaffle_shop.customers        most_recent_order
# 5       model.jaffle_shop.customers         number_of_orders
# 6       model.jaffle_shop.customers  customer_lifetime_value
# 7          model.jaffle_shop.orders                 order_id
# 8          model.jaffle_shop.orders              customer_id
# 9          model.jaffle_shop.orders               order_date
# 10         model.jaffle_shop.orders                   status
# 11         model.jaffle_shop.orders                   amount
# 12         model.jaffle_shop.orders       credit_card_amount
# 13         model.jaffle_shop.orders            coupon_amount
# 14         model.jaffle_shop.orders     bank_transfer_amount
# 15         model.jaffle_shop.orders         gift_card_amount
# 16  model.jaffle_shop.stg_customers              customer_id
# 17   model.jaffle_shop.stg_payments               payment_id
# 18   model.jaffle_shop.stg_payments           payment_method
# 19     model.jaffle_shop.stg_orders                 order_id
# 20     model.jaffle_shop.stg_orders                   status
#
#                                           description
# 0          This is a unique identifier for a customer
# 1                         Customer's first name. PII.
# 2                          Customer's last name. PII.
# 3              Date (UTC) of a customer's first order
# 4        Date (UTC) of a customer's most recent order
# 5   Count of the number of orders a customer has p...
# 6            Total value (AUD) of a customer's orders
# 7            This is a unique identifier for an order
# 8                  Foreign key to the customers table
# 9                Date (UTC) that the order was placed
# 10  Orders can be one of the following statuses:\n...
# 11                    Total amount (AUD) of the order
# 12  Amount of the order (AUD) paid for by credit card
# 13       Amount of the order (AUD) paid for by coupon
# 14  Amount of the order (AUD) paid for by bank tra...
# 15    Amount of the order (AUD) paid for by gift card
# 16
# 17
# 18
# 19
# 20

# %%
comb = columns_df.merge(tests_df, how='left',
                 left_on = ['node','column_name'],
                 right_on = ['node','column_name'],
                ).fillna('')

# %%
comb.head(5)
# Out:
#                       relation table_name                         node  \
# 0  DBT_TABLEAU.DAVID.customers  customers  model.jaffle_shop.customers
# 1  DBT_TABLEAU.DAVID.customers  customers  model.jaffle_shop.customers
# 2  DBT_TABLEAU.DAVID.customers  customers  model.jaffle_shop.customers
# 3  DBT_TABLEAU.DAVID.customers  customers  model.jaffle_shop.customers
# 4  DBT_TABLEAU.DAVID.customers  customers  model.jaffle_shop.customers
#
#    column_name                                 description  \
# 0  customer_id  This is a unique identifier for a customer
# 1  customer_id  This is a unique identifier for a customer
# 2  customer_id  This is a unique identifier for a customer
# 3   first_name                 Customer's first name. PII.
# 4    last_name                  Customer's last name. PII.
#
#                                              test_id      test_type  \
# 0  test.jaffle_shop.unique_customers_customer_id....         unique
# 1  test.jaffle_shop.not_null_customers_customer_i...       not_null
# 2  test.jaffle_shop.relationships_orders_customer...  relationships
# 3
# 4
#
#                                             test_sql
# 0  select\n    customer_id as unique_field,\n    ...
# 1  select *\nfrom DBT_TABLEAU.DAVID.customers\nwh...
# 2  with child as (\n    select customer_id as fro...
# 3
# 4

# %%
catalog['nodes']['model.jaffle_shop.customers']['columns']['customer_id'.upper()]['type']
# Out:
# 'NUMBER'

# %%
comb['column_type'] = comb.apply(lambda x:
                        catalog['nodes'][x['node']]['columns'][x['column_name'].upper()]['type'],axis =1
                                
                                )

# %%
comb.head(5)
# Out:
#                       relation table_name                         node  \
# 0  DBT_TABLEAU.DAVID.customers  customers  model.jaffle_shop.customers
# 1  DBT_TABLEAU.DAVID.customers  customers  model.jaffle_shop.customers
# 2  DBT_TABLEAU.DAVID.customers  customers  model.jaffle_shop.customers
# 3  DBT_TABLEAU.DAVID.customers  customers  model.jaffle_shop.customers
# 4  DBT_TABLEAU.DAVID.customers  customers  model.jaffle_shop.customers
#
#    column_name                                 description  \
# 0  customer_id  This is a unique identifier for a customer
# 1  customer_id  This is a unique identifier for a customer
# 2  customer_id  This is a unique identifier for a customer
# 3   first_name                 Customer's first name. PII.
# 4    last_name                  Customer's last name. PII.
#
#                                              test_id      test_type  \
# 0  test.jaffle_shop.unique_customers_customer_id....         unique
# 1  test.jaffle_shop.not_null_customers_customer_i...       not_null
# 2  test.jaffle_shop.relationships_orders_customer...  relationships
# 3
# 4
#
#                                             test_sql column_type
# 0  select\n    customer_id as unique_field,\n    ...      NUMBER
# 1  select *\nfrom DBT_TABLEAU.DAVID.customers\nwh...      NUMBER
# 2  with child as (\n    select customer_id as fro...      NUMBER
# 3                                                           TEXT
# 4                                                           TEXT

# %%
export = comb.groupby(by = ['relation', 'table_name', 'node', 'column_name', 'column_type','description'],
            as_index=False).agg({'test_type':list, 'test_sql':list})

# %%
export['test_type'] = export['test_type'].apply(';'.join )
export['test_sql'] = export['test_sql'].apply(';\n'.join)

# %%
# export.to_excel("output.xlsx")

# %%
def calc_length(column):
    return max(column.apply(lambda x: max([len(y) for y in x.split('\n')])))

def get_column(number):
    return chr(ord('@')+number)

def get_full_column(number):
    return get_column(number) + ':' + get_column(number)

# %%
import xlsxwriter

# %%
# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter('pandas_simple.xlsx', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
export.to_excel(writer, sheet_name='Sheet1',
                startrow=1, header=False, index=False)

# Get the xlsxwriter objects from the dataframe writer object.
workbook  = writer.book
worksheet = writer.sheets['Sheet1']

# %%
center = workbook.add_format({
#     'align':    'center',
    'valign':   'vcenter'})

# %%
# Set column_widths
for i, col in enumerate(export.columns):
    worksheet.set_column(get_full_column(i+1), min(
        max(calc_length(export[col]), len(col)),
        50), center)

# %%
wrap = workbook.add_format({'text_wrap': True})
# Set the format but not the column width.
worksheet.set_column('G:G', calc_length(export['test_sql']), wrap)
# Out:
# 0

# %%
column_settings = [{'header': column} for column in export.columns]
(max_row, max_col) = export.shape

worksheet.add_table(0, 0, max_row, max_col - 1, {'columns': column_settings})
worksheet.set_default_row(20)

# %%
workbook.close()
